# %%
! pip install seaborn

import pandas as pd
import seaborn as sns
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
auto=pd.read_csv('/content/drive/MyDrive/Automobile_data.csv')
auto.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
# univarient distribution

sns.displot(auto['normalized-losses'])
plt.show()

# %%
sns.displot(auto['engine-size'],kde=False, rug=True)
plt.show()

# %%
# kind= scatter, reg, resid, kde, hex, optional
sns.jointplot(auto['wheel-base'], kind="hex")
plt.show()

# %%
sns.jointplot(auto['wheel-base'], kind="reg")
plt.show()

# %%
sns.jointplot(auto['wheel-base'], kind="resid")
plt.show()

# %%
sns.jointplot(auto['engine-size'], kind="kde")
plt.show()

# %%
sns.jointplot(auto['wheel-base'], kind="scatter")
plt.show()

# %%
sns.pairplot(auto[['normalized-losses','engine-size','horsepower',]])

# %%
sns.stripplot(auto['horsepower'], jitter=True)
# Out:
# <Axes: ylabel='horsepower'>

# %%
sns.swarmplot(auto['horsepower'])
# Out:
# <Axes: ylabel='horsepower'>

# %%
sns.boxplot(auto['horsepower'])
# Out:
# <Axes: ylabel='horsepower'>

# %%
sns.barplot(auto['horsepower'])
# Out:
# <Axes: ylabel='horsepower'>

# %%
sns.countplot(auto['body-style'])
# Out:
# <Axes: xlabel='count', ylabel='body-style'>

# %%
sns.pointplot(auto['horsepower'])
# Out:
# <Axes: ylabel='horsepower'>

# %%
sns.pointplot(x='horsepower', y='fuel-system', data=auto, hue='fuel-system')
# Out:
# <Axes: xlabel='horsepower', ylabel='fuel-system'>
